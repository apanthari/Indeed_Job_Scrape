# %%
import pandas as pd 
all_jobs = pd.read_csv('all_jobs_cleaned.csv') #789
all_jobs
# Out:
#      status                                              title  \
# 0       NEW                         Direct Data Entry Operator
# 1       NEW                      Cloud Data Architect-Director
# 2       NEW                                        Data Aide 2
# 3       NEW          Field Applications Engineer - Data Center
# 4       NEW                                Analyst, YouthTruth
# ...     ...                                                ...
# 9762    NEW                             Data Scientist Analyst
# 9763    NEW            IT Project Manager - Infrastructure M&A
# 9764    NEW  PhD Software Engineer, Early Career, AI/Machin...
# 9765    NEW  PhD Software Engineer, Early Career, AI/Machin...
# 9766    NEW              SAP Master Data Governance (MDG) Lead
#
#                     company                location        date  \
# 0          WESTAMERICA BANK     Fairfield, CA 94534  2024-10-17
# 1                    CEDENT       San Francisco, CA  2024-10-03
# ...

# %%
#randomly select 600 jobs 
manually_labeled_set = all_jobs.sample(n=600)
manually_labeled_set
# Out:
#      status                                              title  \
# 1791    NEW                              Senior, Data Engineer
# 9308    NEW                          Store Scanning Specialist
# 2969    NEW                     Marketing Applied Scientist II
# 22      NEW  Research Data Analyst (Hybrid Opportunity, 2 Y...
# 1542    NEW                       Bioinformatics Data Engineer
# ...     ...                                                ...
# 3018    NEW                            Director, Data & Impact
# 880     NEW  Senior Director, Data & Analytics - Availabili...
# 792     NEW                           Principal Data Scientist
# 1497    NEW                          Data Engineer, E-Commerce
# 6768    NEW                       Construction Project Manager
#
#                       company                 location        date  \
# 1791                  Walmart      Sunnyvale, CA 94086  2024-11-07
# 9308           RetailData LLC                 Apex, NC  2024-10-28
# ...

# %%
#manually_labeled_set.to_csv("manually_labeled_set.csv", index=False)

# %%
import pandas as pd
manually_labeled_set = pd.read_csv('manually_labeled_set.csv') #789

# %%
#split it in half 
anuja_unlab = manually_labeled_set.iloc[0:300]
#sai_unlab = = manually_labeled_set.iloc[]
anuja_unlab
anuja_unlab.to_csv("anuja_unlab.csv", index=False)

# %%
sai_unlab = manually_labeled_set.iloc[301:600]
sai_unlab
# Out:
#      status                                              title  \
# 7668    NEW                                      Data Engineer
# 4003    NEW             Data Analytics Specialist Intermediate
# 4278    NEW                                  Data Analyst (NY)
# 793     NEW    Project Manager - Data Centers (Silicon Valley)
# 3030    NEW                              Data Entry Specialist
# ...     ...                                                ...
# 3018    NEW                            Director, Data & Impact
# 880     NEW  Senior Director, Data & Analytics - Availabili...
# 792     NEW                           Principal Data Scientist
# 1497    NEW                          Data Engineer, E-Commerce
# 6768    NEW                       Construction Project Manager
#
#                            company                 location        date  \
# 7668                       Infosys           Richardson, TX  2024-11-07
# ...

# %%
sai_unlab.to_csv("sai_unlab.csv", index=False)
